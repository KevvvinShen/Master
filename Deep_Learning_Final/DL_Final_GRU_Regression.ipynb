# %%
# Basic packages always been used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data scaling
from sklearn.preprocessing import MinMaxScaler

# Function for spilting training & testing data set
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV

# Tensorflow sequential models
from tensorflow import keras
from keras import backend as clear
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU, BatchNormalization
from keras.optimizers import SGD, Adam
from keras.wrappers.scikit_learn import KerasRegressor

# Functions for evaluation
from sklearn.metrics import mean_absolute_error #MAE
from sklearn.metrics import mean_squared_error #MSE,RMSE
from sklearn.metrics import mean_absolute_percentage_error #MAPE

# %%
# Symmetric Mean Absolute Percentage Error (SMAPE)
def SMAPE_calulate(y_true, y_pred):
    n = len(y_true)
    SMAPE=(100 / n) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))
    return SMAPE

# Relative Absolute Error (RAE)
def RAE_calculate(y_true, y_pred):
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    return RAE

# Mean Relative Absolute Error (MRAE)
def MRAE_calculate(y_true, y_pred):
    n=len(y_true)
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    MRAE=RAE/n
    return MRAE

# Median Relative Absolute Error (MdRAE) comparing with benchmark
# Note: By default, the bench value is the mean of actual value
def MdRAE_calculate(y_true, y_pred, bench=None):
    if bench==None:
        bench=np.mean(y_true)
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE,bench
    else:
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE
    
# Relative Squared Error (RSE) & Root Relative Squared Error (RRSE)
def RSE_calculate(y_true, y_pred, Root=False):
    mse = np.mean((y_true - y_pred)**2)
    denominator = np.var(y_true)
    RSE=mse/denominator
    
    if Root==True:
        return np.sqrt(RSE)
    else:
        return RSE

# %%
#load data(sometimes need to use "/")
#df = pd.read_csv('D:/pythonData/python_demo_data/Rainfall_Forecast.csv')
# Colab
df = pd.read_csv('nasdaq2000~2023.csv')
df
# Out:
#            Date          Open          High           Low         Close  \
# 0      2000/1/3   4186.189941   4192.189941   3989.709961   4131.149902
# 1      2000/1/4   4020.000000   4073.250000   3898.229980   3901.689941
# 2      2000/1/5   3854.350098   3924.209961   3734.870117   3877.540039
# 3      2000/1/6   3834.439941   3868.760010   3715.620117   3727.129883
# 4      2000/1/7   3711.090088   3882.669922   3711.090088   3882.620117
# ...         ...           ...           ...           ...           ...
# 5883  2023/5/22  12664.440430  12756.230470  12655.259770  12720.780270
# 5884  2023/5/23  12652.879880  12709.740230  12554.429690  12560.250000
# 5885  2023/5/24  12481.889650  12529.629880  12415.849610  12484.160160
# 5886  2023/5/25  12706.440430  12736.919920  12604.889650  12698.089840
# 5887  2023/5/26  12736.419920  13001.910160  12729.740230  12975.690430
#
#          Adj Close      Volume
# 0      4131.149902  1510070000
# 1      3901.689941  1511840000
# 2      3877.540039  1735670000
# 3      3727.129883  1598320000
# 4      3882.620117  1634930000
# ...            ...         ...
# 5883  12720.780270  4278920000
# 5884  12560.250000  4347440000
# 5885  12484.160160   359790000
# 5886  12698.089840  4651640000
# 5887  12975.690430  4434070000
#
# [5888 rows x 7 columns]

# %%
new_df=df.iloc[:,[0,4]].copy()
new_df.head()
# Out:
#        Date        Close
# 0  2000/1/3  4131.149902
# 1  2000/1/4  3901.689941
# 2  2000/1/5  3877.540039
# 3  2000/1/6  3727.129883
# 4  2000/1/7  3882.620117

# %%
new_df.describe()
# Out:
#               Close
# count   5888.000000
# mean    4741.215218
# std     3628.343348
# min     1114.109985
# 25%     2156.997497
# 50%     3000.054931
# 75%     6286.185059
# max    16057.440430

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('NASDAQ 2000/1/3~2023/5/26',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Close',fontsize=18,weight='bold')

# Actual by predicted plot
plt.plot(new_df['Date'],new_df['Close'],marker='.',color='blue')

# Set the axis
plt.xticks(df['Date'][::800],fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Create 3 lags
new_df['Lag_1']=new_df['Close'].shift(1).copy()
new_df['Lag_2']=new_df['Close'].shift(2).copy()
new_df['Lag_3']=new_df['Close'].shift(3).copy()
new_df.head()
# Out:
#        Date        Close        Lag_1        Lag_2        Lag_3
# 0  2000/1/3  4131.149902          NaN          NaN          NaN
# 1  2000/1/4  3901.689941  4131.149902          NaN          NaN
# 2  2000/1/5  3877.540039  3901.689941  4131.149902          NaN
# 3  2000/1/6  3727.129883  3877.540039  3901.689941  4131.149902
# 4  2000/1/7  3882.620117  3727.129883  3877.540039  3901.689941

# %%
# Drop out missing values and rest index
clean_df=new_df.dropna(axis=0, how='any').copy()
clean_df=clean_df.reset_index(drop=True)
clean_df
# Out:
#            Date         Close         Lag_1         Lag_2         Lag_3
# 0      2000/1/6   3727.129883   3877.540039   3901.689941   4131.149902
# 1      2000/1/7   3882.620117   3727.129883   3877.540039   3901.689941
# 2     2000/1/10   4049.669922   3882.620117   3727.129883   3877.540039
# 3     2000/1/11   3921.189941   4049.669922   3882.620117   3727.129883
# 4     2000/1/12   3850.020020   3921.189941   4049.669922   3882.620117
# ...         ...           ...           ...           ...           ...
# 5880  2023/5/22  12720.780270  12657.900390  12688.839840  12500.570310
# 5881  2023/5/23  12560.250000  12720.780270  12657.900390  12688.839840
# 5882  2023/5/24  12484.160160  12560.250000  12720.780270  12657.900390
# 5883  2023/5/25  12698.089840  12484.160160  12560.250000  12720.780270
# 5884  2023/5/26  12975.690430  12698.089840  12484.160160  12560.250000
#
# [5885 rows x 5 columns]

# %%
clean_df.describe()
# Out:
#               Close         Lag_1         Lag_2         Lag_3
# count   5885.000000   5885.000000   5885.000000   5885.000000
# mean    4741.608296   4740.062306   4738.567591   4737.148218
# std     3629.225495   3627.654807   3626.187185   3624.789377
# min     1114.109985   1114.109985   1114.109985   1114.109985
# 25%     2156.899902   2156.899902   2156.899902   2156.899902
# 50%     2996.689941   2996.689941   2996.689941   2996.689941
# 75%     6295.680176   6283.020020   6278.410156   6275.060059
# max    16057.440430  16057.440430  16057.440430  16057.440430

# %%
x = clean_df.drop(['Date', 'Close'],axis=1).copy()
x.head()
# Out:
#          Lag_1        Lag_2        Lag_3
# 0  3877.540039  3901.689941  4131.149902
# 1  3727.129883  3877.540039  3901.689941
# 2  3882.620117  3727.129883  3877.540039
# 3  4049.669922  3882.620117  3727.129883
# 4  3921.189941  4049.669922  3882.620117

# %%
y = clean_df['Close'].copy()
y.head()
# Out:
# 0    3727.129883
# 1    3882.620117
# 2    4049.669922
# 3    3921.189941
# 4    3850.020020
# Name: Close, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,shuffle=False)

# %%
x_train_tuning, x_valid, y_train_tuning, y_valid = train_test_split(x_train,y_train,test_size=0.2,shuffle=False)

# %%
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train_tuning)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']
scaled_x_train
# Out:
#          Lag_1     Lag_2     Lag_3
# 0     0.702357  0.708495  0.766815
# 1     0.664128  0.702357  0.708495
# 2     0.703648  0.664128  0.702357
# 3     0.746106  0.703648  0.664128
# 4     0.713451  0.746106  0.703648
# ...        ...       ...       ...
# 3761  0.897240  0.872719  0.887290
# 3762  0.923696  0.897240  0.872719
# 3763  0.928011  0.923696  0.897240
# 3764  0.932088  0.928011  0.923696
# 3765  0.928021  0.932088  0.928011
#
# [3766 rows x 3 columns]

# %%
from keras.losses import mse
from keras.backend import sqrt

def my_RMSE(y_true, y_pred):
    return sqrt(mse(y_true, y_pred))

# Register custom object
#from keras.utils.generic_utils import get_custom_objects for pc
from tensorflow.keras.saving import get_custom_objects
get_custom_objects().update({'my_RMSE': my_RMSE})

# %%
def create_model(learning_rate=0.01):
    # 6.1 Create the model
    clear.clear_session()
    model=Sequential()

    # 6.2 Add input layer & first hidden layer
    model.add(GRU(units=50, return_sequences = True, input_shape = (x_train.shape[1], 1)))

    # 6.3 Add second hidden layer
    model.add(GRU(units=25, return_sequences = True, input_shape = (x_train.shape[1], 1)))

    model.add(Dropout(rate=0.2))

    # 6.4 Add third hidden layer
    model.add(GRU(units=50))

    # 6.5 Add output layer
    model.add(Dense(units=1, activation='sigmoid'))

    # 6.6 Compile the defined Net
    #opt=SGD(learning_rate=0.001,momentum=0.5)
    opt=Adam(learning_rate=learning_rate,beta_1=0.9)
    model.compile(loss='binary_crossentropy',optimizer=opt, metrics=['accuracy'])

    # Finally check the model 
    return model

model = KerasRegression(build_fn=create_model, epochs=100,verbose=0)
cv_inner = TimeSeriesSplit(n_splits=3)
learning_rate = [0.01,0.001,0.0001]
batch_size = [32,64]
param_grid = dict(batch_size=batch_size,learning_rate=learning_rate)
grid = GridSearchCV(estimator=model,param_grid=param_grid,cv=cv_inner,scoring='neg_root_mean_squared_error',n_jobs=-1)
grid_result = grid.fit(x_train, y_train)

print("Best:%fusing%s"%(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_11376\3880721668.py:28: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100,verbose=0)
# Best:-1823.262746using{'batch_size': 32, 'learning_rate': 0.01}
# -1823.262746 (1050.254592) with: {'batch_size': 32, 'learning_rate': 0.01}
# -3313.175626 (1386.771971) with: {'batch_size': 32, 'learning_rate': 0.001}
# -3527.444742 (1467.261103) with: {'batch_size': 32, 'learning_rate': 0.0001}
# -2486.212976 (1110.123324) with: {'batch_size': 64, 'learning_rate': 0.01}
# -3429.210069 (1431.047159) with: {'batch_size': 64, 'learning_rate': 0.001}
# -3538.819342 (1471.210959) with: {'batch_size': 64, 'learning_rate': 0.0001}

# %%
train_data=clean_df.iloc[0:4704,:].copy()
train_data
# Out:
#            Date        Close        Lag_1        Lag_2        Lag_3
# 0      2000/1/6  3727.129883  3877.540039  3901.689941  4131.149902
# 1      2000/1/7  3882.620117  3727.129883  3877.540039  3901.689941
# 2     2000/1/10  4049.669922  3882.620117  3727.129883  3877.540039
# 3     2000/1/11  3921.189941  4049.669922  3882.620117  3727.129883
# 4     2000/1/12  3850.020020  3921.189941  4049.669922  3882.620117
# ...         ...          ...          ...          ...          ...
# 4699  2018/9/11  7972.470215  7924.160156  7902.540039  7922.729980
# 4700  2018/9/12  7954.229980  7972.470215  7924.160156  7902.540039
# 4701  2018/9/13  8013.709961  7954.229980  7972.470215  7924.160156
# 4702  2018/9/14  8010.040039  8013.709961  7954.229980  7972.470215
# 4703  2018/9/17  7895.790039  8010.040039  8013.709961  7954.229980
#
# [4704 rows x 5 columns]

# %%
test_data=clean_df.iloc[4704:5884,:].copy()
test_data
# Out:
#            Date         Close         Lag_1         Lag_2         Lag_3
# 4704  2018/9/18   7956.109863   7895.790039   8010.040039   8013.709961
# 4705  2018/9/19   7950.040039   7956.109863   7895.790039   8010.040039
# 4706  2018/9/20   8028.229980   7950.040039   7956.109863   7895.790039
# 4707  2018/9/21   7986.959961   8028.229980   7950.040039   7956.109863
# 4708  2018/9/24   7993.250000   7986.959961   8028.229980   7950.040039
# ...         ...           ...           ...           ...           ...
# 5879  2023/5/19  12657.900390  12688.839840  12500.570310  12343.049810
# 5880  2023/5/22  12720.780270  12657.900390  12688.839840  12500.570310
# 5881  2023/5/23  12560.250000  12720.780270  12657.900390  12688.839840
# 5882  2023/5/24  12484.160160  12560.250000  12720.780270  12657.900390
# 5883  2023/5/25  12698.089840  12484.160160  12560.250000  12720.780270
#
# [1180 rows x 5 columns]

# %%
new_train_data = clean_df.drop(['Date', 'Close'],axis=1).copy()
new_test_data = clean_df['Close'].copy()

# %%
# Create the model
clear.clear_session()
model=Sequential()

# 6.2 Add input layer & first hidden layer
model.add(GRU(units=50, return_sequences = True, input_shape = (x_train.shape[1], 1)))

# 6.3 Add second hidden layer
model.add(GRU(units=25, return_sequences = True, input_shape = (x_train.shape[1], 1)))

model.add(Dropout(rate=0.2))

# 6.4 Add third hidden layer
model.add(GRU(units=50))

# 6.5 Add output layer
model.add(Dense(units=1, activation='sigmoid'))

# 6.6 Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=learning_rate,beta_1=0.9)
model.compile(loss='binary_crossentropy',optimizer=opt, metrics=['accuracy'])

# Finally check the model 
Fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 6,421
# Trainable params: 6,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=Fmodel.fit(new_train_data, new_test_data, epochs=100, batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 1s 1ms/step - loss: 217693.2656 - mean_absolute_percentage_error: 3.7101
# Epoch 2/100
# 184/184 [==============================] - 0s 1ms/step - loss: 25097.6934 - mean_absolute_percentage_error: 2.1500
# Epoch 3/100
# 184/184 [==============================] - 0s 2ms/step - loss: 34782.9844 - mean_absolute_percentage_error: 2.4905
# Epoch 4/100
# 184/184 [==============================] - 0s 1ms/step - loss: 33904.2812 - mean_absolute_percentage_error: 2.4734
# Epoch 5/100
# 184/184 [==============================] - 0s 2ms/step - loss: 46060.6133 - mean_absolute_percentage_error: 2.7569
# Epoch 6/100
# 184/184 [==============================] - 0s 1ms/step - loss: 32828.4141 - mean_absolute_percentage_error: 2.4441
# Epoch 7/100
# 184/184 [==============================] - 0s 1ms/step - loss: 32673.3184 - mean_absolute_percentage_error: 2.4128
# Epoch 8/100
# 184/184 [==============================] - 0s 1ms/step - loss: 42966.4336 - mean_absolute_percentage_error: 2.9220
# Epoch 9/100
# 184/184 [==============================] - 0s 1ms/step - loss: 39314.3359 - mean_absolute_percentage_error: 2.7225
# Epoch 10/100
# 184/184 [==============================] - 0s 1ms/step - loss: 46551.7852 - mean_absolute_percentage_error: 2.6902
# Epoch 11/100
# 184/184 [==============================] - 0s 1ms/step - loss: 29888.9297 - mean_absolute_percentage_error: 2.2834
# Epoch 12/100
# 184/184 [==============================] - 0s 2ms/step - loss: 33853.1602 - mean_absolute_percentage_error: 2.4470
# Epoch 13/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20733.2109 - mean_absolute_percentage_error: 1.8611
# Epoch 14/100
# 184/184 [==============================] - 0s 1ms/step - loss: 31186.2402 - mean_absolute_percentage_error: 2.3614
# Epoch 15/100
# 184/184 [==============================] - 0s 1ms/step - loss: 28247.6074 - mean_absolute_percentage_error: 2.2336
# Epoch 16/100
# 184/184 [==============================] - 0s 2ms/step - loss: 22604.3281 - mean_absolute_percentage_error: 2.0393
# Epoch 17/100
# 184/184 [==============================] - 0s 1ms/step - loss: 41294.9570 - mean_absolute_percentage_error: 2.6002
# Epoch 18/100
# 184/184 [==============================] - 0s 1ms/step - loss: 34636.3203 - mean_absolute_percentage_error: 2.4606
# Epoch 19/100
# 184/184 [==============================] - 0s 1ms/step - loss: 27606.4863 - mean_absolute_percentage_error: 2.2634
# Epoch 20/100
# 184/184 [==============================] - 0s 1ms/step - loss: 27641.2246 - mean_absolute_percentage_error: 2.2167
# Epoch 21/100
# 184/184 [==============================] - 0s 1ms/step - loss: 41904.7852 - mean_absolute_percentage_error: 2.8329
# Epoch 22/100
# 184/184 [==============================] - 0s 1ms/step - loss: 15347.6230 - mean_absolute_percentage_error: 1.6492
# Epoch 23/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19264.8281 - mean_absolute_percentage_error: 1.7911
# Epoch 24/100
# 184/184 [==============================] - 0s 1ms/step - loss: 51023.2305 - mean_absolute_percentage_error: 2.9615
# Epoch 25/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19999.0410 - mean_absolute_percentage_error: 1.9481
# Epoch 26/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18241.6797 - mean_absolute_percentage_error: 1.8268
# Epoch 27/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16064.6875 - mean_absolute_percentage_error: 1.6926
# Epoch 28/100
# 184/184 [==============================] - 0s 1ms/step - loss: 22490.6367 - mean_absolute_percentage_error: 2.0075
# Epoch 29/100
# 184/184 [==============================] - 0s 2ms/step - loss: 30628.3203 - mean_absolute_percentage_error: 2.2643
# Epoch 30/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20668.5195 - mean_absolute_percentage_error: 1.9990
# Epoch 31/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19091.6230 - mean_absolute_percentage_error: 1.8193
# Epoch 32/100
# 184/184 [==============================] - 0s 1ms/step - loss: 14964.2871 - mean_absolute_percentage_error: 1.6041
# Epoch 33/100
# 184/184 [==============================] - 0s 1ms/step - loss: 35188.5312 - mean_absolute_percentage_error: 2.5072
# Epoch 34/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20299.6914 - mean_absolute_percentage_error: 1.9029
# Epoch 35/100
# 184/184 [==============================] - 0s 1ms/step - loss: 29768.6152 - mean_absolute_percentage_error: 2.3165
# Epoch 36/100
# 184/184 [==============================] - 0s 1ms/step - loss: 15953.9570 - mean_absolute_percentage_error: 1.6711
# Epoch 37/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20951.5664 - mean_absolute_percentage_error: 1.9280
# Epoch 38/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16939.0176 - mean_absolute_percentage_error: 1.7556
# Epoch 39/100
# 184/184 [==============================] - 0s 1ms/step - loss: 23428.2422 - mean_absolute_percentage_error: 2.1287
# Epoch 40/100
# 184/184 [==============================] - 0s 1ms/step - loss: 15062.9805 - mean_absolute_percentage_error: 1.5793
# Epoch 41/100
# 184/184 [==============================] - 0s 1ms/step - loss: 29460.3984 - mean_absolute_percentage_error: 2.3133
# Epoch 42/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18547.6641 - mean_absolute_percentage_error: 1.8529
# Epoch 43/100
# 184/184 [==============================] - 0s 1ms/step - loss: 24920.6289 - mean_absolute_percentage_error: 2.1319
# Epoch 44/100
# 184/184 [==============================] - 0s 1ms/step - loss: 22828.3516 - mean_absolute_percentage_error: 1.9616
# Epoch 45/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13248.5088 - mean_absolute_percentage_error: 1.5247
# Epoch 46/100
# 184/184 [==============================] - 0s 1ms/step - loss: 25533.0449 - mean_absolute_percentage_error: 2.1756
# Epoch 47/100
# 184/184 [==============================] - 0s 1ms/step - loss: 26660.8965 - mean_absolute_percentage_error: 2.2381
# Epoch 48/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17843.2656 - mean_absolute_percentage_error: 1.7949
# Epoch 49/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20446.1543 - mean_absolute_percentage_error: 1.9101
# Epoch 50/100
# 184/184 [==============================] - 0s 2ms/step - loss: 21110.5156 - mean_absolute_percentage_error: 1.9023
# Epoch 51/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18133.4082 - mean_absolute_percentage_error: 1.7882
# Epoch 52/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13762.7803 - mean_absolute_percentage_error: 1.5452
# Epoch 53/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19512.5469 - mean_absolute_percentage_error: 1.8365
# Epoch 54/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17815.6348 - mean_absolute_percentage_error: 1.8250
# Epoch 55/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18196.1230 - mean_absolute_percentage_error: 1.7852
# Epoch 56/100
# 184/184 [==============================] - 0s 2ms/step - loss: 29014.7324 - mean_absolute_percentage_error: 2.2076
# Epoch 57/100
# 184/184 [==============================] - 0s 1ms/step - loss: 35677.6953 - mean_absolute_percentage_error: 2.4616
# Epoch 58/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16600.8828 - mean_absolute_percentage_error: 1.7036
# Epoch 59/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18331.2402 - mean_absolute_percentage_error: 1.7810
# Epoch 60/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19783.8887 - mean_absolute_percentage_error: 1.8507
# Epoch 61/100
# 184/184 [==============================] - 0s 1ms/step - loss: 12558.4199 - mean_absolute_percentage_error: 1.4946
# Epoch 62/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13958.1211 - mean_absolute_percentage_error: 1.5869
# Epoch 63/100
# 184/184 [==============================] - 0s 1ms/step - loss: 26519.7520 - mean_absolute_percentage_error: 2.1218
# Epoch 64/100
# 184/184 [==============================] - 0s 1ms/step - loss: 26627.2734 - mean_absolute_percentage_error: 2.2410
# Epoch 65/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20974.7539 - mean_absolute_percentage_error: 1.9319
# Epoch 66/100
# 184/184 [==============================] - 0s 1ms/step - loss: 22893.8164 - mean_absolute_percentage_error: 2.0048
# Epoch 67/100
# 184/184 [==============================] - 0s 1ms/step - loss: 14369.1230 - mean_absolute_percentage_error: 1.5812
# Epoch 68/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20102.0977 - mean_absolute_percentage_error: 1.8852
# Epoch 69/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13006.5410 - mean_absolute_percentage_error: 1.5064
# Epoch 70/100
# 184/184 [==============================] - 0s 2ms/step - loss: 30505.8262 - mean_absolute_percentage_error: 2.3232
# Epoch 71/100
# 184/184 [==============================] - 0s 1ms/step - loss: 12207.8506 - mean_absolute_percentage_error: 1.4734
# Epoch 72/100
# 184/184 [==============================] - 0s 1ms/step - loss: 18541.1055 - mean_absolute_percentage_error: 1.7796
# Epoch 73/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16716.7070 - mean_absolute_percentage_error: 1.7228
# Epoch 74/100
# 184/184 [==============================] - 0s 1ms/step - loss: 11560.4404 - mean_absolute_percentage_error: 1.4184
# Epoch 75/100
# 184/184 [==============================] - 0s 1ms/step - loss: 21215.8320 - mean_absolute_percentage_error: 1.9910
# Epoch 76/100
# 184/184 [==============================] - 0s 1ms/step - loss: 26511.5000 - mean_absolute_percentage_error: 2.1021
# Epoch 77/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17073.3242 - mean_absolute_percentage_error: 1.6864
# Epoch 78/100
# 184/184 [==============================] - 0s 1ms/step - loss: 28454.5586 - mean_absolute_percentage_error: 2.1943
# Epoch 79/100
# 184/184 [==============================] - 0s 1ms/step - loss: 11470.9395 - mean_absolute_percentage_error: 1.4170
# Epoch 80/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17882.5195 - mean_absolute_percentage_error: 1.7866
# Epoch 81/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17563.6465 - mean_absolute_percentage_error: 1.7037
# Epoch 82/100
# 184/184 [==============================] - 0s 1ms/step - loss: 15660.4775 - mean_absolute_percentage_error: 1.5946
# Epoch 83/100
# 184/184 [==============================] - 0s 1ms/step - loss: 14985.3877 - mean_absolute_percentage_error: 1.6518
# Epoch 84/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16411.6934 - mean_absolute_percentage_error: 1.7458
# Epoch 85/100
# 184/184 [==============================] - 0s 1ms/step - loss: 10648.9834 - mean_absolute_percentage_error: 1.3809
# Epoch 86/100
# 184/184 [==============================] - 0s 1ms/step - loss: 20439.9258 - mean_absolute_percentage_error: 1.8609
# Epoch 87/100
# 184/184 [==============================] - 0s 1ms/step - loss: 24619.4375 - mean_absolute_percentage_error: 2.1281
# Epoch 88/100
# 184/184 [==============================] - 0s 2ms/step - loss: 16469.9102 - mean_absolute_percentage_error: 1.7756
# Epoch 89/100
# 184/184 [==============================] - 0s 1ms/step - loss: 15852.1309 - mean_absolute_percentage_error: 1.7006
# Epoch 90/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19660.2637 - mean_absolute_percentage_error: 1.9068
# Epoch 91/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17721.6992 - mean_absolute_percentage_error: 1.8384
# Epoch 92/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13065.8242 - mean_absolute_percentage_error: 1.5069
# Epoch 93/100
# 184/184 [==============================] - 0s 1ms/step - loss: 14021.8789 - mean_absolute_percentage_error: 1.5506
# Epoch 94/100
# 184/184 [==============================] - 0s 1ms/step - loss: 13502.2812 - mean_absolute_percentage_error: 1.5511
# Epoch 95/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16518.7734 - mean_absolute_percentage_error: 1.6582
# Epoch 96/100
# 184/184 [==============================] - 0s 1ms/step - loss: 22468.9434 - mean_absolute_percentage_error: 2.0575
# Epoch 97/100
# 184/184 [==============================] - 0s 1ms/step - loss: 16860.5820 - mean_absolute_percentage_error: 1.7185
# Epoch 98/100
# 184/184 [==============================] - 0s 1ms/step - loss: 12548.1123 - mean_absolute_percentage_error: 1.4544
# Epoch 99/100
# 184/184 [==============================] - 0s 1ms/step - loss: 17374.6484 - mean_absolute_percentage_error: 1.8256
# Epoch 100/100
# 184/184 [==============================] - 0s 1ms/step - loss: 19669.9141 - mean_absolute_percentage_error: 1.9279

# %%
Fmodel.save('House_Rent_ANN_trained_model.h5')
print('Model has been saved...')
# Out:
# Model has been saved...

# %%
ANN_model=keras.models.load_model('House_Rent_ANN_trained_model.h5')
print('Model successfully loaded...')
# Out:
# Model successfully loaded...

# %%
# X test
x_forecast_test=test_data.drop(['Date','Close'],axis=1).copy()
# Y test
y_forecast_test=test_data['Close'].copy()

# %%
# 8.1 Make prediction 
prediction=np.round((ANN_model.predict_on_batch(x_forecast_test)),2)
pred_values=[]
for i in range(0,len(prediction)):
    value=prediction[i][0]
    pred_values.append(value)

# %%
Results=pd.DataFrame({'Date':test_data['Date'],'Close_true':test_data['Close'],'Predict':pred_values})
Results['abs Error']=np.abs(Results['Close_true']-Results['Predict'])
Results
# Out:
#            Date    Close_true       Predict   abs Error
# 4704  2018/9/18   7956.109863   8035.839844   79.729981
# 4705  2018/9/19   7950.040039   8070.319824  120.279785
# 4706  2018/9/20   8028.229980   8069.479980   41.250000
# 4707  2018/9/21   7986.959961   8136.399902  149.439941
# 4708  2018/9/24   7993.250000   8112.500000  119.250000
# ...         ...           ...           ...         ...
# 5879  2023/5/19  12657.900390  12841.230469  183.330079
# 5880  2023/5/22  12720.780270  12847.360352  126.580082
# 5881  2023/5/23  12560.250000  12902.660156  342.410156
# 5882  2023/5/24  12484.160160  12775.700195  291.540035
# 5883  2023/5/25  12698.089840  12691.759766    6.330074
#
# [1180 rows x 4 columns]

# %%
# 8.2 Calculating the mertics
MAE=mean_absolute_error(y_forecast_test,pred_values)
MSE=mean_squared_error(y_forecast_test,pred_values,squared=True)
RMSE=mean_squared_error(y_forecast_test,pred_values,squared=False)
MAPE=mean_absolute_percentage_error(y_forecast_test,pred_values)
SMAPE=SMAPE_calulate(y_forecast_test,pred_values)
RAE=RAE_calculate(y_forecast_test,pred_values)
MRAE=MRAE_calculate(y_forecast_test,pred_values)
MdRAE=MdRAE_calculate(y_forecast_test,pred_values)
RSE=RSE_calculate(y_forecast_test,pred_values,Root=False)
RRSE=RSE_calculate(y_forecast_test,pred_values,Root=True)

print('MAE:',round(MAE,3))
print('MSE:',round(MSE,3))
print('RMSE:',round(RMSE,3))
print('MAPE:',round(MAPE*100,3),'%')
print('SMAPE:',round(SMAPE,3),'%')
print('RAE:',round(RAE,3))
print('MRAE:',MRAE)
print('MdRAE:',round(MdRAE[0],3),'bench:',round(MdRAE[1],3))
print('RSE:',round(RSE,3))
print('RRSE:',round(RRSE,3))
# Out:
# MAE: 188.833
# MSE: 58723.484
# RMSE: 242.329
# MAPE: 1.739 %
# SMAPE: 1.717 %
# RAE: 0.084
# MRAE: 7.125050216369397e-05
# MdRAE: 0.07 bench: 10996.877
# RSE: 0.009
# RRSE: 0.093

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('NASDAQ2000~2023',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Close',fontsize=18,weight='bold')

# Comparison of actual value and predicted value according to Date
plt.plot(new_df['Date'],new_df['Close'],marker='o',color='blue',label='Actual')
plt.plot(Results['Date'],Results['Predict'],marker='o',color='red',label='Forecast')

# Set the axis
plt.xticks(clean_df['Date'][::400], fontsize=16)
plt.yticks(fontsize=16)

# Set legends
plt.legend(loc=4,fontsize=20)

plt.show()

# %%
# Lock the scale of axis by Y_true
max_value=20000+5
min_value=0-5

# Figure setting
plt.figure(figsize=(10,10),dpi=300)
plt.title('Actual by predicted plot',weight='bold',fontsize=24)
plt.xlabel('Actual (Y-true)',fontsize=18,weight='bold')
plt.ylabel('Forecast',fontsize=18,weight='bold')

# Perfect model reference line
plt.plot([min_value,max_value], [min_value,max_value], linestyle='--',color='red')

# Actual by predicted plot
plt.scatter(Results.iloc[:,1],Results.iloc[:,2],marker='.',color='blue')

# Set the axis
plt.ylim(0-5,max_value)
plt.xlim(0-5,max_value)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
